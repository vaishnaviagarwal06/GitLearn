# %%
from langchain_core.documents import Document

# %%
doc = Document(page_content="Hello, world!", metadata={"name": "JYOTHI","class": "Document extraction"})
doc
# Out:
# Document(metadata={'name': 'JYOTHI', 'class': 'Document extraction'}, page_content='Hello, world!')

# %%
import os
os.makedirs("data/text_files", exist_ok=True)

# %%
sample_texts={
    "./data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "./data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}
for filepath,content in sample_texts.items():
    with open(filepath, "w") as f:
        f.write(content)

# %%
from langchain.document_loaders import TextLoader 

from langchain_community.document_loaders import TextLoader

# %%
loader=TextLoader("data/text_files/python_intro.txt")
document=loader.load()
document
# Out:
# [Document(metadata={'source': 'data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': 'data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.'),
#  Document(metadata={'source': 'data/text_files/machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n    \n    \n    ')]

# %%
from langchain_community.document_loaders import PyPDFLoader

dir_loader=DirectoryLoader(
    "data/pdf_files",
    glob="**/*.pdf",
    loader_cls=PyPDFLoader,
    show_progress=False
)
documents=dir_loader.load() 
documents
# Out:
# [Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 0, 'page_label': '1'}, page_content='JSM YT'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 1, 'page_label': '2'}, page_content='Table of Content\nVariables\nOperators\nFunctions\nConditional Statements\nTruthy / Falsy Values \nString Escape Characters\nJavaScript Basics\nString Methods\nArray Methods\nLooping\nArray methods for looping\nString & Array Methods'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 2, 'page_label': '3'}, page_content='Value vs Reference\nMath Object Methods\nDate Object Methods\nMath & Date Methods  \nWindow Object Methods\nWindow Object Properties\nWindow Object  \nInput Events\nMouse Events\nHTML DOM Events\nHTML DOM Event Properties & Methods\nDOM Events & Properties'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 3, 'page_label': '4'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 4, 'page_label': '5'}, page_content="Variables\nvar variableName = value\nCan be reassigned and are only available inside the \nfunction they're created in. Its function scoped.\nconst variableName = value \nCannot be reassigned and not accessible before \nthey appear within the code. Its block scoped.\nlet variableName = value \nIt can be reassigned but its similar to const i.e. block \nscoped.\nA block is a set of opening and closing curly brackets.\nWhat is the block? \nIf variables are not created inside a function or block \nthey are globally scoped."),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 5, 'page_label': '6'}, page_content='Variables\nPrimitive Data Types:\nNumber \nString\nBoolean\nNull\nUndefined\nSymbol\n5, 6.5, 7 etc\n“Hello everyone” etc\ntrue or false\nrepresents null i.e. no value at all\nA variable that has not been \nassigned a value is\xa0undefined.\n5, 6.5, 7 etc\n“Hello everyone” etc\ntrue or false\nrepresents null i.e. no value at all\nA variable that has not been \nassigned a value is\xa0undefined.\nused as an identifier for object \nproperties.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 6, 'page_label': '7'}, page_content='Variables\nObject\nArray\nRegExp\nNon-Primitive Data Types:\ninstance through which we can \naccess members\ngroup of similar values\nrepresents regular expression'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 7, 'page_label': '8'}, page_content='Operators\nBasic Operators\n+ Addition\n- Subtraction\n* Multiplication\n/ Division\n() Grouping operator\n% Modulus (remainder)\n++ Increment numbers\n-- Decrement numbers'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 8, 'page_label': '9'}, page_content='Operators\nComparison Operators\n== Equal to\n=== Equal value and equal type\n!= Not equal\n!== Not equal value or not equal type\n> Greater than\n< Less than\n>= Greater than or equal to\n<= Less than or equal to'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 9, 'page_label': '10'}, page_content="Operators\nLogical Operators\n&& Logical and\n|| Logical or\n! Logical not\nBitwise operators in Javascript are mostly used for \nnumerical conversions/computations, because \nsometimes they're much faster than their Math or \nparseInt equivalents\nBitwise Operators"),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 10, 'page_label': '11'}, page_content='Operators\nBitwise Operators\n& AND statement\n| OR statement\n~ NOT\n^ XOR\n<< Zero fill left shift\n>> Signed right shift\n>>> Zero Fill right shift'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 11, 'page_label': '12'}, page_content='Functions\nNormal Function Declaration\nfunction name (parameter) {\n  \n}\n// statements\nFunction stored in a variable\nlet name = function (parameter) {\n  \n}\n// statements\nArrow Function\nconst name = (parameter) => {\n  \n}\n// statements'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 12, 'page_label': '13'}, page_content='Conditional Statements\nIf - Else Statements\nif (condition) {  \n  \n} else {  \n  \n}\n// code to be executed if the \n     condition is true\n// code to be executed if the \n     condition is false\nUse  to specify a block of code to be executed, if \na specified condition is true\nif\nUse  to specify a block of code to be \nexecuted, if the same condition is false\nelse\nUse  to specify a new condition to test, if the \nfirst condition is false\nelse if\nUse  to specify many alternative blocks of \ncode to be executed\nswitch'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 13, 'page_label': '14'}, page_content='Conditional Statements\nIf - Else If - Else Statements\nif (condition1) {  \n  \n} else if (condition2) {  \n  \n} else {  \n  \n}\n// code to be executed if the \n     condition is true\n\n// code to be executed if the \n     condition1 is false and \n     condition2 is true\n\n// code to be executed if \n     condition1 is false and \n     condition2 is false'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 14, 'page_label': '15'}, page_content='Conditional Statements\nSwitch Statement\nswitch(expression) {\n  case x:\n    \n    break;\n  case y:\n    \n    break;\n  default:\n    \n} \n// code block\n// code block\n// code block\nThe switch expression is evaluated once.\nThe value of the expression is compared with the \nvalues of each case.\nIf there is a match, the associated block of code is \nexecuted.\nIf there is no match, the default code block is \nexecuted.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 15, 'page_label': '16'}, page_content='Conditional Statements\nTernary Operator\ncondition ? exprIfTrue : exprIfFalse\nAn expression whose value is used as a condition.\ncondition\nAn expression which is executed if the condition is \ntruthy.\nexprIfTrue\nAn expression which is executed if the condition is \nfalsy.\nexprIfFalse'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 16, 'page_label': '17'}, page_content='Truthy / Falsy Values \nFALSY Values\nTRUTHY Values\nfalse\n0 (zero)\n"", \'\', `` (empty strings)\nnull\nundefined\nNaN (not a number)\nEverything that is not FALSY\nNote  :  Empty array ([]) is not\xa0falsy'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 17, 'page_label': '18'}, page_content='Strings\nEscape Characters\nlet variableName = “Hello world” \n\\\' Single quote\n\\" Double quote\n\\\\ Backslash\n\\b Backspace\n\\f Form feed\n\\n New line\n\\r Carriage return \n\\t Horizontal tabulator\n\\v Vertical Tabulator'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 18, 'page_label': '19'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 19, 'page_label': '20'}, page_content="String Methods  \nstring[index]\nget a certain character of a string\nstring.length\nreturn the number of characters in a string\nstring.split(' ')\nreturns an array of words of a string\nstring.split('')\nreturns an array of characters of a string\nstring.toLowerCase()\nreturns a lowercased string\nstring.toUpperCase()\nreturns an uppercased string"),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 20, 'page_label': '21'}, page_content='String Methods  \nstring.charAt(index)\nreturns a new string consisting of the single \ncharacter located at the specified offset into the \nstring. \nstring.replace(substr, newSubstr)\nreturns a new string with a substring (substr) \nreplaced by a new one (newSubstr).\nstring.includes(searchString)\nperforms a case-sensitive search to determine \nwhether one string may be found within another \nstring, returns true or false.\nstring.substr(start, length)\nreturns a portion of the string, starting at the \nspecified index and extending for a given number.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 21, 'page_label': '22'}, page_content="String Methods  \nstring.includes('subtring')\nchecks whether a substring exists inside of a string \n[check the character case]\nstring.indexOf(searchValue)\nreturns the index of the first occurrence of the \nspecified value, starting the search at fromIndex. \nReturns -1 if the value is not found. \nstring.lastIndexOf(searchValue)\nreturns the index of the last occurrence of the \nspecified value, searching backwards from \nfromIndex. Returns -1 if the value is not found. \nstring.slice(beginIndex, endIndex)\nextracts a section of a string and returns it as a new \nstring, without modifying the original string."),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 22, 'page_label': '23'}, page_content='Array Methods  \narray[index]\nreturns a certain value from an array\npush(value)\nadds the value to the end of the array\npop()\nremoves the value from the end of the array\nshift()\nremoves the value from the start of the array\nunshift(value)\nadds the value to the start of the array\nsplice(fromIndex, no_of_elements)\nremoves the number_of_elements, starting from \nfromIndex from the array'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 23, 'page_label': '24'}, page_content="Array Methods  \nslice(fromIndex, toIndex)\ncopies a certain part of the array\nconcat()\nJoin several arrays into one\njoin('')\nreturns a string of array values\narray.length\nreturns the number of elements in the array\nreverse()\nreverse the order of the elements in an array\ntoString()\nreturns a string representing the specified array \nand its elements."),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 24, 'page_label': '25'}, page_content='Array Methods  \ntoString()\nreturns a string representing the specified array \nand its elements. \nincludes(searchElement)\ndetermines whether an array includes a certain \nvalue among its entries, returning true or false as \nappropriate. \nsort()\nIt sorts the elements of an array in place and returns \nthe sorted array. It sorts an array alphabetically.\nindexOf(searchElement)\nreturns the index of the first occurance of that value\nlastIndexOf(searchElement)\nreturns the index of the last occurance of that value'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 25, 'page_label': '26'}, page_content='Looping\nwhile (condition) {\n  \n}\n// code block to be executed\nWhile Loop\nfor (st 1; st 2; st 3) {\n  \n}\n// code block to be executed\nFor Loop\nst 1 is executed (one time) before the \nexecution of the code block.\nst 2 defines the condition for executing the \ncode block.\nst 3 is executed (every time) after the code \nblock has been executed.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 26, 'page_label': '27'}, page_content='Looping\nfor (key in object) {\n  \n}\n// code block to be executed\nFor In Loop\nfor (variable of iterable) {\n  \n}\n// code block to be executed\nFor Of Loop\ndo {\n}\nwhile (condition);\n  // code block to be executed\nDo While Loop'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 27, 'page_label': '28'}, page_content='Array methods for looping\narray.forEach()\narray.forEach((element, index) => {\n  \n})\n// code block to be executed\nIt executes a provided function once for each array \nelement. \narray.map()\narray.map((element, index) => {\n  \n})\n// code block to be executed\nIt creates a new array populated with the results of \ncalling a provided function on every element in the \ncalling array.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 28, 'page_label': '29'}, page_content='Array method for looping\narray.filter()\narray.filter((element, index) => {\n  \n})\n// code block to be executed\nIt creates a new array with all elements that pass the \ntest implemented by the provided function.\narray.findIndex()\narray.findIndex((el, idx, arr) => {\n  \n})\n// code block to be executed\nIt returns the index of the first element in the array that \nsatisfies the provided testing function'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 29, 'page_label': '30'}, page_content='Array method for looping\narray.some()\narray.some((el, index, array)) => {\n  \n})\n// code block to be executed\nIt tests whether at least one element in the array \npasses the test implemented by the provided function\narray.every()\narray.every((element, index) => {\n  \n})\n// code block to be executed\nIt tests whether all elements in the array pass the test \nimplemented by the provided function. It returns a \nBoolean value.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 30, 'page_label': '31'}, page_content='Array method for looping\narray.reduce()\narray.reduce((\n)) => {\n  \n})\nprevValue,currentValue,\ncurrentIndex, array\n// code block to be executed\nIt runs a function on each array element to produce \n(reduce it to) a single value. It works from left-to-right.\narray.reduceRight()\narray.reduceRight((\n)) => {\n  \n})\naccumulator, \ncurrentValue, index, array\n// code block to be executed\nIt runs a function on each array element to produce \n(reduce it to) a single value. It works from right-to-left.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 31, 'page_label': '32'}, page_content='VALUE VS REFERENCE\nArrays\nObjects'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 32, 'page_label': '33'}, page_content='VALUE VS REFERENCE\nCloning Array\nOne Level Deep'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 33, 'page_label': '34'}, page_content='VALUE VS REFERENCE\nCloning Array\nTwo Level Deep'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 34, 'page_label': '35'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 35, 'page_label': '36'}, page_content='Math Object\nabs(x)\nReturns the absolute value of x\nacos(x)\nReturns the arccosine of x, in radians\nacosh(x)\nReturns the hyperbolic arccosine of x\nasin(x)\nReturns the arcsine of x, in radians\nasinh(x)\nReturns the hyperbolic arcsine of x\natan(x)\nReturns the arctangent of x as a numeric value \nbetween -PI/2 and PI/2 radians'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 36, 'page_label': '37'}, page_content='Math Object\natan2(y, x)\nReturns the arctangent of the quotient of its arguments\natanh(x)\nReturns the hyperbolic arctangent of x\ncbrt(x)\nReturns the cubic root of x\nceil(x)\nReturns x, rounded upwards to the nearest integer\ncos(x)\nReturns the cosine of x (x is in radians)\ncosh(x)\nReturns the hyperbolic cosine of x'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 37, 'page_label': '38'}, page_content='Math Object\nexp(x)\nReturns the value of Ex\nfloor(x)\nReturns x, rounded downwards to the nearest integer\nlog(x)\nReturns the natural logarithm (base E) of x\nmax(x, y, z, ..., n)\nReturns the number with the highest value\nmin(x, y, z, ..., n)\nReturns the number with the lowest value\npow(x, y)\nReturns the value of x to the power of y'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 38, 'page_label': '39'}, page_content='Math Object\nrandom()\nReturns a random number between 0 and 1\nround(x)\nRounds x to the nearest integer\nsign(x)\nReturns if x is negative, null or positive (-1, 0, 1)\nsin(x)\nReturns the sine of x (x is in radians)\nsinh(x)\nReturns the square root of x\nsqrt(x)\nReturns the square root of x'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 39, 'page_label': '40'}, page_content='Math Object\ntan(x)\nReturns the tangent of an angle\ntanh(x)\nReturns the hyperbolic tangent of a number\ntrunc(x)\nReturns the integer part of a number (x)'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 40, 'page_label': '41'}, page_content='Date Objects\ngetFullYear()\nGet the year as a four digit number (yyyy)\ngetMonth()\nGet the month as a number (0-11)\ngetDate()\nGet the day as a number (1-31)\ngetHours()\nGet the hour (0-23)\ngetMinutes()\nGet the minute (0-59)\nGet Date Methods'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 41, 'page_label': '42'}, page_content='Date Objects\ngetTime()\nGet the time (milliseconds since January 1, 1970)\ngetDay()\nGet the weekday as a number (0-6)\nDate.now()\nGet the time. ECMAScript 5.\ngetSeconds()\nGet the second (0-59)\ngetMilliseconds()\nGet the millisecond (0-999)'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 42, 'page_label': '43'}, page_content='Date Objects\ngetUTCDate()\nSame as getDate(), but returns the UTC date\ngetUTCDay()\nSame as getDay(), but returns the UTC day\ngetUTCFullYear()\nSame as getFullYear(), but returns the UTC year\ngetUTCMonth()\nSame as getMonth(), but returns the UTC month\ngetUTCHours()\nSame as getHours(), but returns the UTC hour\nUTC Date Methods'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 43, 'page_label': '44'}, page_content='Date Objects\ngetUTCMinutes()\nSame as getMinutes(), but returns the UTC minutes\ngetUTCSeconds()\nSame as getSeconds(), but returns the UTC seconds\ngetUTCMilliseconds()\nSame as getMilliseconds(), but returns the UTC \nmilliseconds'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 44, 'page_label': '45'}, page_content='Date Objects\nsetDate()\nSet the day as a number (1-31)\nsetFullYear()\nSet the year (optionally month and day)\nsetMonth()\nSet the month (0-11)\nsetHours()\nSet the hour (0-23)\nsetMinutes()\nSet the minutes (0-59)\nSet Date Methods'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 45, 'page_label': '46'}, page_content='Date Objects\nsetSeconds()\nSet the seconds (0-59)\nsetMilliseconds()\nSet the milliseconds (0-999)\nsetTime()\nSet the time (milliseconds since January 1, 1970)'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 46, 'page_label': '47'}, page_content='Date Objects\nnew Date()\nCreates a new date object with the current date and \ntime\nnew Date(year, month, ...)\ncreates a new date object with a specified date and \ntime\nnew Date(dateString)\ncreates a new date object from a date string\nnew Date(milliseconds)\ncreates a new date object as zero time plus \nmilliseconds'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 47, 'page_label': '48'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 48, 'page_label': '49'}, page_content='Window Object Methods\nalert()\nDisplays an alert box with a message & an OK button\natob()\nDecodes a base-64 encoded string\nblur()\nRemoves focus from the current window\nbtoa()\nEncodes a string in base-64\nclearInterval()\nClears a timer set with setInterval()\nclearTimeout()\nClears a timer set with setTimeout()'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 49, 'page_label': '50'}, page_content='Window Object Methods\nclose()\nCloses the current window\nconfirm()\nDisplays a dialog box with a message and an OK and \na Cancel button\ngetComputedStyle()\nGets the current computed CSS styles applied to an \nelement\ngetSelection()\nReturns a Selection object representing the range of \ntext selected by the user\nmatchMedia()\nReturns a MediaQueryList object representing the \nspecified CSS media query string'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 50, 'page_label': '51'}, page_content='Window Object Methods\nfocus()\nSets focus to the current window\nmoveBy()\nMoves a window relative to its current position\nmoveTo()\nMoves a window to the specified position\nopen()\nOpens a new browser window\nprint()\nPrints the content of the current window\nprompt()\nDisplays a dialog box that prompts the visitor for \ninput'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 51, 'page_label': '52'}, page_content='Window Object Methods\nrequestAnimationFrame()\nRequests the browser to call a function to update an \nanimation before the next repaint\nresizeBy()\nResizes the window by the specified pixels\nresizeTo()\nResizes the window to the specified width and height\nscrollBy()\nScrolls the document by the  number of pixels\nscrollTo()\nScrolls the document to the specified coordinates\nstop()\nStops the window from loading'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 52, 'page_label': '53'}, page_content='Window Object Methods\nsetInterval()\nCalls a function or evaluates an expression at \nspecified intervals (in milliseconds)\nsetTimeout()\nCalls a function or evaluates an expression after a \nspecified number of milliseconds'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 53, 'page_label': '54'}, page_content="Window Object Properties\nclosed\nReturns a Boolean value indicating whether a window \nhas been closed or not\nconsole\nReturns a reference to the Console object, which \nprovides methods for logging information to the \nbrowser's console\ndefaultStatus\nSets or returns the default text in the statusbar of a \nwindow\ndocument\nReturns the Document object for the window (See \nDocument object)\nframes\nReturns all <iframe> elements in the current window"),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 54, 'page_label': '55'}, page_content="Window Object Properties\nhistory\nReturns the History object for the window\ninnerHeight\nReturns the height of the window's content area \n(viewport) including scrollbars\ninnerWidth\nReturns the width of a window's content area \n(viewport) including scrollbars\nlength\nReturns the number of <iframe> elements in the \ncurrent window\nlocalStorage\nAllows to save key/value pairs in a web browser. \nStores the data with no expiration date"),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 55, 'page_label': '56'}, page_content='Window Object Properties\nlocation\nReturns the Location object for the window\nname\nSets or returns the name of a window\nnavigator\nReturns the Navigator object for the window \nopener\nReturns a reference to the window that created the \nwindow\nparent\nReturns the parent window of the current window\nself\nReturns the current window'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 56, 'page_label': '57'}, page_content='Window Object Properties\nouterHeight\nReturns the height of the browser window, including \ntoolbars/scrollbars\nouterWidth\nReturns the width of the browser window, including \ntoolbars/scrollbars\npageXOffset\nReturns the pixels the current document has been \nscrolled (horizontally) from the upper left corner of \nthe window\npageYOffset\nReturns the pixels the current document has been \nscrolled (vertically) from the upper left corner of the \nwindow'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 57, 'page_label': '58'}, page_content='Window Object Properties\nscreen\nReturns the Screen object for the window \nscreenLeft\nReturns the horizontal coordinate of the window \nrelative to the screen\nscreenTop\nReturns the vertical coordinate of the window relative \nto the screen\nscreenX\nReturns the horizontal coordinate of the window \nrelative to the screen\nscreenY\nReturns the vertical coordinate of the window relative \nto the screen'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 58, 'page_label': '59'}, page_content='Window Object Properties\nsessionStorage\nAllows to save key/value pairs in a web browser. \nStores the data for one session\nscrollX\nAn alias of pageXOffset\nscrollY\nAn alias of pageYOffset\nstatus\nSets or returns the text in the statusbar of a window\ntop\nReturns the topmost browser window'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 59, 'page_label': '60'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 60, 'page_label': '61'}, page_content='Input Events\nonblur\nWhen a user leaves an input field\nonchange\nWhen a user changes the content of an input field\nonfocus\nWhen an input field gets focus\nonselect\nWhen input text is selected\nonsubmit\nWhen a user clicks the submit button\nonreset\nWhen a user clicks the reset button'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 61, 'page_label': '62'}, page_content='Input Events\nonkeydown\nWhen a user is pressing/holding down a key\nonkeypress\nWhen a user is pressing/holding down a key\nonkeyup\nWhen the user releases a key\nonkeydown\nWhen the user is pressing a key'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 62, 'page_label': '63'}, page_content='Mouse Events\nonclick\nWhen the user clicks on an element\noncontextmenu\nWhen the user right-clicks on an element to open a \ncontext menu\nondblclick\nWhen the user double-clicks on an element\nonmouseenter\nWhen the pointer is moved onto an element\nonmouseleave\nWhen the pointer is moved out of an element\nonmousemove\nwhen the pointer is moving while it is over an element'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 63, 'page_label': '64'}, page_content='Mouse Events\nonmousedown\nWhen the user presses a mouse button over an \nelement\nonmouseout\nWhen a user moves the mouse pointer out of an \nelement, or out of one of its children\nonmouseover\nWhen the pointer is moved onto an element, or onto \none of its children\nonmouseup\nwhen a user releases a mouse button over an \nelement'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 64, 'page_label': '65'}, page_content='HTML DOM Events\nabort\nThe event occurs when the loading of a media is \naborted\nafterprint\nThe event occurs when a page has started printing, \nor if the print dialogue box has been closed\nanimationend\nThe event occurs when a CSS animation has \ncompleted\nanimationiteration\nThe event occurs when a CSS animation is repeated\nanimationstart\nThe event occurs when a CSS animation has started'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 65, 'page_label': '66'}, page_content='HTML DOM Events\nbeforeprint\nThe event occurs when a page is about to be printed\nbeforeunload\nThe event occurs before the document is about to be \nunloaded\nblur\nThe event occurs when an element loses focus\ncanplay\nThe event occurs when the browser can start playing \nthe media (when it has buffered enough to begin)\ncanplaythrough\nThe event occurs when the browser can play through \nthe media without stopping for buffering'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 66, 'page_label': '67'}, page_content='HTML DOM Events\nchange\nThe event occurs when the content of a form \nelement, or the checked state have changed \nclick\nThe event occurs when the user clicks on an element\ncontextmenu\nThe event occurs when the user right-clicks on an \nelement to open a context menu\ncopy\nThe event occurs when the user copies the content of \nan element\ncut\nThe event occurs when the user cuts the content of \nan element'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 67, 'page_label': '68'}, page_content='HTML DOM Events\ndblclick\nThe event occurs when the user double-clicks on an \nelement\ndrag\nThe event occurs when an element is being dragged\ndragend\nThe event occurs when the user has finished \ndragging an element\ndragenter\nThe event occurs when the dragged element enters \nthe drop target\ndragleave\nThe event occurs when the dragged element leaves \nthe drop target'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 68, 'page_label': '69'}, page_content='HTML DOM Events\ndragover\nThe event occurs when the dragged element is over \nthe drop target\ndragstart\nThe event occurs when the user starts to drag an \nelement\ndrop\nThe event occurs when the dragged element is \ndropped on the drop target\ndurationchange\nThe event occurs when the duration of the media is \nchanged\nended\nThe event occurs when the media has reach the end \n(useful for messages like "thanks for listening")'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 69, 'page_label': '70'}, page_content='HTML DOM Events\nerror\nThe event occurs when an error occurs while loading \nan external file \nfocus\nThe event occurs when an element gets focus\nfocusin\nThe event occurs when an element is about to get \nfocus\nfocusout\nThe event occurs when an element is about to lose \nfocus\nfullscreenchange\nThe event occurs when an element is displayed in \nfullscreen mode'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 70, 'page_label': '71'}, page_content='HTML DOM Events\nfullscreenerror\nThe event occurs when an element can not be \ndisplayed in fullscreen mode\ninput\nThe event occurs when an element gets user input\ninvalid\nThe event occurs when an element is invalid\nkeydown\nThe event occurs when the user is pressing a key\nkeypress\nThe event occurs when the user presses a key\nkeyup\nThe event occurs when the user releases a key'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 71, 'page_label': '72'}, page_content='HTML DOM Events\nload\nThe event occurs when an object has loaded\nloadeddata\nThe event occurs when media data is loaded\nloadedmetadata\nThe event occurs when meta data (like dimensions \nand duration) are loaded\nloadstart\nThe event occurs when the browser starts looking for \nthe specified media\nmessage\nThe event occurs when a message is received \nthrough the event source'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 72, 'page_label': '73'}, page_content='HTML DOM Events\nmousedown\nThe event occurs when the user presses a mouse \nbutton over an element\nmouseenter\nThe event occurs when the pointer is moved onto an \nelement\nmouseleave\nThe event occurs when the pointer is moved out of \nan element\nmousemove\nThe event occurs when the pointer is moving while it \nis over an element\nmouseover\nThe event occurs when the pointer is moved onto an \nelement, or onto one of its children'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 73, 'page_label': '74'}, page_content='HTML DOM Events\nmouseout\nThe event occurs when a user moves the mouse \npointer out of an element, or out of one of its children\nmouseup\nThe event occurs when a user releases a mouse \nbutton over an element\noffline\nThe event occurs when the browser starts to work \noffline\nonline\nThe event occurs when the browser starts to work \nonline\nopen\nThe event occurs when a connection with the event \nsource is opened'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 74, 'page_label': '75'}, page_content='HTML DOM Events\npagehide\nThe event occurs when the user navigates away from \na webpage\npageshow\nThe event occurs when the user navigates to a \nwebpage\npaste\nThe event occurs when the user pastes some content \nin an element\npause\nThe event occurs when the media is paused either by \nthe user or programmatically\nplay\nThe event occurs when the media has been started \nor is no longer paused'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 75, 'page_label': '76'}, page_content="HTML DOM Events\nplaying\nThe event occurs when the media is playing after \nhaving been paused or stopped for buffering\npopstate\nThe event occurs when the window's history changes\nprogress\nThe event occurs when the browser is in the process \nof getting the media data (downloading the media)\nratechange\nThe event occurs when the playing speed of the \nmedia is changed\nresize\nThe event occurs when the document view is resized"),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 76, 'page_label': '77'}, page_content='HTML DOM Events\nreset\nThe event occurs when a form is reset\nscroll\nThe event occurs when an element\'s scrollbar is \nbeing scrolled\nsearch\nThe event occurs when the user writes something in \na search field (for <input="search">)\nseeked\nThe event occurs when the user is finished moving/\nskipping to a new position in the media\nseeking\nThe event occurs when the user starts moving/\nskipping to a new position in the media'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 77, 'page_label': '78'}, page_content='HTML DOM Events\nselect\nThe event occurs after the user selects some text (for \n<input> and <textarea>)\nshow\nThe event occurs when a <menu> element is shown \nas a context menu\nstalled\nThe event occurs when the browser is trying to get \nmedia data, but data is not available\nstorage\nThe event occurs when a Web Storage area is \nupdated\nsubmit\nThe event occurs when a form is submitted'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 78, 'page_label': '79'}, page_content='HTML DOM Events\nsuspend\nThe event occurs when the browser is intentionally \nnot getting media data\ntimeupdate\nThe event occurs when the playing position has \nchanged (like when the user fast forwards to a \ndifferent point in the media)\ntoggle\nThe event occurs when the user opens or closes the \n<details> element\ntouchcancel\nThe event occurs when the touch is interrupted\ntouchend\nThe event occurs when a finger is removed from a \ntouch screen'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 79, 'page_label': '80'}, page_content='HTML DOM Events\ntouchmove\nThe event occurs when a finger is dragged across \nthe screen\ntouchstart\nThe event occurs when a finger is placed on a touch \nscreen\ntransitionend\nThe event occurs when a CSS transition has \ncompleted\nunload\nThe event occurs once a page has unloaded (for \n<body>)\nvolumechange\nThe event occurs when the volume of the media has \nchanged (includes setting the volume to "mute")'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 80, 'page_label': '81'}, page_content='HTML DOM Events\nwaiting\nThe event occurs when the media has paused but is \nexpected to resume (like when the media pauses to \nbuffer more data)\nwheel\nThe event occurs when the mouse wheel rolls up or \ndown over an element\nhashchange\nThe event occurs when there has been changes to \nthe anchor part of a URL'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 81, 'page_label': '82'}, page_content='HTML DOM Event \nProperties and Methods\naltKey\nReturns whether the "ALT" key was pressed when the \nmouse event was triggered\nanimationName\nReturns the name of the animation\nbubbles\nReturns whether or not a specific event is a bubbling \nevent\nbutton\nReturns which mouse button was pressed when the \nmouse event was triggered'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 82, 'page_label': '83'}, page_content='HTML DOM Event \nProperties and Methods\ncancelable\nReturns whether or not an event can have its default \naction prevented\ncharCode\nReturns the Unicode character code of the key that \ntriggered the onkeypress event\nchangeTouches\nReturns a list of all the touch objects whose state \nchanged between the previous touch and this touch\nclientX\nReturns the horizontal coordinate of the mouse \npointer, relative to the current window, when the \nmouse event was triggered'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 83, 'page_label': '84'}, page_content='HTML DOM Event \nProperties and Methods\nclientY\nReturns the vertical coordinate of the mouse pointer, \nrelative to the current window, when the mouse event \nwas triggered\nclipboardData\nReturns an object containing the data affected by \nthe clipboard operation\ncode\nReturns the code of the key that triggered the event\ncomposed\nReturns whether the event is composed or not \ncreateEvent()\nCreates a new event'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 84, 'page_label': '85'}, page_content='HTML DOM Event \nProperties and Methods\nctrlKey\nReturns whether the "CTRL" key was pressed when the \nmouse event was triggered\ncurrentTarget\nReturns the element whose event listeners triggered \nthe event\ndataTransfer\nReturns an object containing the data being \ndragged/dropped, or inserted/deleted\ndefaultPrevented\nReturns whether or not the preventDefault() method \nwas called for the event'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 85, 'page_label': '86'}, page_content='HTML DOM Event \nProperties and Methods\ndeltaX\nReturns the horizontal scroll amount of a mouse \nwheel (x-axis)\ndeltaY\nReturns the vertical scroll amount of a mouse wheel \n(y-axis)\ndeltaZ\nReturns the scroll amount of a mouse wheel for the z-\naxis\ndeltaMode\nReturns a number that represents the unit of \nmeasurements for delta values (pixels, lines or \npages)'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 86, 'page_label': '87'}, page_content='HTML DOM Event \nProperties and Methods\ndetail\nReturns a number that indicates how many times the \nmouse was clicked\nelapsedTime\nReturns the number of seconds an animation or \ntransition has been running\neventPhase\nReturns which phase of the event flow is currently \nbeing evaluated\ngetTargetRanges()\nReturns an array containing target ranges that will be \naffected by the insertion/deletion'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 87, 'page_label': '88'}, page_content='HTML DOM Event \nProperties and Methods\ngetModifierState()\nReturns an array containing target ranges that will be \naffected by the insertion/deletion\ninputType\nReturns the type of the change (i.e "inserting" or \n"deleting")\nisComposing\nReturns whether the state of the event is composing \nor not\nisTrusted\nReturns whether or not an event is trusted'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 88, 'page_label': '89'}, page_content='HTML DOM Event \nProperties and Methods\ndata\nReturns the inserted characters\nkey\nReturns the key value of the key represented by the \nevent or returns the key of the changed storage item\nkeyCode\nReturns the Unicode character code of the key that \ntriggered the onkeypress event, or the Unicode key \ncode of the key that triggered the onkeydown or \nonkeyup event\nlocation\nReturns the location of a key on the keyboard or \ndevice'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/js_cheet_sheet_1730678859.pdf', 'total_pages': 99, 'page': 89, 'page_label': '90'}, page_content='HTML DOM Event \nProperties and Methods\nlengthComputable\nReturns whether the length of the progress can be \ncomputable or not\nloaded\nReturns how much work has been loaded\nmetaKey\nReturns whether the "META" key was pressed when an \nevent was triggered\nMovementX\nReturns the horizontal coordinate of the mouse \npointer relative to the position of the last mousemove \nevent'),
# ...
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 93, 'page_label': '94'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 94, 'page_label': '95'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 95, 'page_label': '96'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 96, 'page_label': '97'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 97, 'page_label': '98'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 98, 'page_label': '99'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 99, 'page_label': '100'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 100, 'page_label': '101'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 101, 'page_label': '102'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 102, 'page_label': '103'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 103, 'page_label': '104'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 104, 'page_label': '105'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 105, 'page_label': '106'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 106, 'page_label': '107'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 107, 'page_label': '108'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 108, 'page_label': '109'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 109, 'page_label': '110'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 110, 'page_label': '111'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 111, 'page_label': '112'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 112, 'page_label': '113'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 113, 'page_label': '114'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 114, 'page_label': '115'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 115, 'page_label': '116'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 116, 'page_label': '117'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 117, 'page_label': '118'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 118, 'page_label': '119'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 119, 'page_label': '120'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 120, 'page_label': '121'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 121, 'page_label': '122'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 122, 'page_label': '123'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 123, 'page_label': '124'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 124, 'page_label': '125'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 125, 'page_label': '126'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 126, 'page_label': '127'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 127, 'page_label': '128'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 128, 'page_label': '129'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 129, 'page_label': '130'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 130, 'page_label': '131'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 131, 'page_label': '132'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 132, 'page_label': '133'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 133, 'page_label': '134'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 134, 'page_label': '135'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 135, 'page_label': '136'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 136, 'page_label': '137'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 137, 'page_label': '138'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 138, 'page_label': '139'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 139, 'page_label': '140'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 140, 'page_label': '141'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 141, 'page_label': '142'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 142, 'page_label': '143'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 143, 'page_label': '144'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 144, 'page_label': '145'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 145, 'page_label': '146'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 146, 'page_label': '147'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 147, 'page_label': '148'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 148, 'page_label': '149'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 149, 'page_label': '150'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 150, 'page_label': '151'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 151, 'page_label': '152'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 152, 'page_label': '153'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 153, 'page_label': '154'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 154, 'page_label': '155'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 155, 'page_label': '156'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 156, 'page_label': '157'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 157, 'page_label': '158'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 158, 'page_label': '159'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 159, 'page_label': '160'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 160, 'page_label': '161'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 161, 'page_label': '162'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'data/pdf_files/JavaScript_Handwritten_Notes__1690868806.pdf', 'total_pages': 163, 'page': 162, 'page_label': '163'}, page_content='')]
